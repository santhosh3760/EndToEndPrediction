# %%
import pandas as pd
df = pd.read_csv("/Users/santhoshreddy/Desktop/vscode/Portfolio_Projects/EndToEndPrediction/data/preprocessed_data.csv")

# %%
df.shape
# Out:
# (85040, 35)

# %%
def inspect_data(dataset_path):
    df = pd.read_csv(dataset_path)
    print(df.head())
    print(df.info())
    print(df.describe())
    print(df.isnull().sum())

# %%
# Call this function in your dataset.py
inspect_data("/Users/santhoshreddy/Desktop/vscode/Portfolio_Projects/EndToEndPrediction/data/preprocessed_data.csv")
# Out:
#    gender  age  admission_type_id  discharge_disposition_id  time_in_hospital  \
# 0       0   15                  1                         0                 3
# 1       0   25                  1                         0                 2
# 2       1   35                  1                         0                 2
# 3       1   45                  1                         0                 1
# 4       1   65                  0                         0                 4
#
#    num_lab_procedures  num_procedures  num_medications  number_inpatient  \
# 0                  59               0               18                 0
# 1                  11               5               13                 1
# 2                  44               1               16                 0
# 3                  51               0                8                 0
# 4                  70               1               21                 0
#
# ...
